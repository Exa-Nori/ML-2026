# %%
import time

import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

import pyro
import pyro.distributions as dist
from pyro.infer import SVI, Trace_ELBO, MCMC, NUTS
from pyro.infer.autoguide import (
    AutoDiagonalNormal,
    AutoMultivariateNormal,
    init_to_median,
    init_to_value,
)

from sklearn.cluster import KMeans
import arviz as az

# %%
def generate_complex_gmm_data_with_labels(n_samples=1500):
    torch.manual_seed(42)

    # 1) Кластер A: широкий (n=600)
    loc_a = torch.tensor([7.5, 2.5])
    data_a = torch.randn(600, 2) * 1.8 + loc_a
    labels_a = torch.zeros(600)

    # 2) Кластер B: вытянутый по диагонали (n=600)
    loc_b = torch.tensor([5.0, 5.0])
    scale_b = torch.tensor([4.5, 0.6])
    theta = torch.tensor([torch.pi / 4])  # 45 градусов
    rot = torch.tensor([[theta.cos(), -theta.sin()], [theta.sin(), theta.cos()]])
    data_b = (torch.randn(600, 2) * scale_b) @ rot.T + loc_b
    labels_b = torch.ones(600)

    # 3) Кластер C: узкий пик рядом с B (n=300)
    loc_c = torch.tensor([3.5, 5.5])
    data_c = torch.randn(300, 2) * 0.2 + loc_c
    labels_c = torch.ones(300) * 2

    # Объединение
    data = torch.cat([data_a, data_b, data_c])
    labels = torch.cat([labels_a, labels_b, labels_c])
    # Перемешивание с сохранением соответствия меток
    idx = torch.randperm(n_samples)
    return data[idx], labels[idx]


data_2d, true_labels = generate_complex_gmm_data_with_labels()

plt.figure(figsize=(10, 7))
colors = ['#1f77b4', '#ff7f0e', '#d62728']
for i, lbl in enumerate(['A', 'B', 'C']):
    mask = (true_labels == i)
    plt.scatter(data_2d[mask, 0], data_2d[mask, 1], 
                s=10, alpha=0.6, c=colors[i], label=f'Cluster {lbl}')


plt.title("Ground Truth")
plt.legend()
#plt.axis('equal')
plt.xlim(-8, 15)
plt.grid(True, alpha=0.2)
plt.show()

# %% [markdown]
# Модель смеси mean-field, определяю вероятностную модель GMM в Pyro

# %%
def model_mf(data, K=3):
    D = data.shape[1]  # Размерность данных
    # Dirichlet(1.0) равномерное распределение весов компонентов смеси
    weights = pyro.sample("weights", dist.Dirichlet(torch.ones(K)))
    with pyro.plate("components", K):
        # Средние для каждого кластера
        locs = pyro.sample("locs", dist.Normal(torch.zeros(D), 1.0).to_event(1))
        # Масштабы для каждого кластера
        scales = pyro.sample("scales", dist.LogNormal(torch.zeros(D), 1.0).to_event(1))

    mixing_dist = dist.Categorical(weights)
    # Объединение компонентов в одну смесь
    component_dist = dist.Normal(locs, scales).to_event(1)
    mixture = dist.MixtureSameFamily(mixing_dist, component_dist)
    
    with pyro.plate("data", len(data)):
        pyro.sample("obs", mixture, obs=data)


pyro.render_model(model_mf, model_args=(data_2d,), render_distributions=True)

# %%
from pyro.infer.autoguide import AutoDiagonalNormal, init_to_median

pyro.clear_param_store()

guide = AutoDiagonalNormal(model_mf, init_loc_fn=init_to_median)

# %% [markdown]
# Обучение SVI
# Оптимизирую параметры guide так, чтобы приближать постериорное распределение

# %%
adam = pyro.optim.Adam({"lr": 0.01})
svi = SVI(model_mf, guide, adam, loss=Trace_ELBO())

# Цикл обучения
n_steps = 2000
losses = []

start_time = time.time()
for step in range(n_steps):
    loss = svi.step(data_2d)
    losses.append(loss)
    if step % 500 == 0:
        print(f"Step {step} - Loss: {loss:.2f}")

duration = time.time() - start_time
print(f"Обучение завершено за {duration:.2f} сек.")
# Out:
# Step 0 - Loss: 72605.22
# Step 500 - Loss: 8945.06
# Step 1000 - Loss: 8177.55
# Step 1500 - Loss: 7646.40
# Обучение завершено за 17.52 сек.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot(losses)
plt.title("ELBO Loss")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# Извлекаем средние значения locs и стандартные отклонения scales

# %%
with torch.no_grad():
    medians = guide.median()
    final_locs = medians['locs']
    final_scales = medians['scales']

# %%
from matplotlib.patches import Ellipse

def plot_results(data, locs, scales, title):
    plt.figure(figsize=(10, 7))
    plt.scatter(data[:, 0], data[:, 1], s=10, alpha=0.3, c='gray')
    
    ax = plt.gca()
    for i in range(len(locs)):
        # Эллипс 2-sigma (накрывает ~95% данных)
        # width и height диаметры, поэтому умножаю scale на 2 для sigma и на 2 (ля диаметра = 4
        el = Ellipse(xy=locs[i], width=4*scales[i, 0], height=4*scales[i, 1], 
                     angle=0, color=colors[i], fill=False, linewidth=3, label=f'Cluster {i}')
        ax.add_patch(el)
        
    plt.title(title)
    plt.legend()
    plt.show()

plot_results(data_2d, final_locs, final_scales, "Basic VI Results (Diagonal Covariance)")

# %% [markdown]
# Запускаю обычный K-means из sklearn

# %%
km = KMeans(n_clusters=3, n_init=10).fit(data_2d.numpy())
km_centers = torch.tensor(km.cluster_centers_, dtype=torch.float)

def init_loc_fn(site):
    if site["name"] == "locs":
        return km_centers
    if site["name"] == "scales":
        return torch.ones_like(site["value"]) # Начальный масштаб = 1
    return init_to_median(site)

pyro.clear_param_store()
guide_km = AutoDiagonalNormal(model_mf, init_loc_fn=init_loc_fn)

# %% [markdown]
# Повторный запуск SVI с KMeans и `guide_km`

# %%
# === 6) Повторный запуск SVI с KMeans-инициализированным `guide_km` ===
# Предполагается, что в предыдущей ячейке уже создан `guide_km`.

adam = pyro.optim.Adam({"lr": 0.01})
# Используем здесь guide_km!
svi = SVI(model_mf, guide_km, adam, loss=Trace_ELBO())

# --- Цикл обучения ---
n_steps = 2000
losses = []
start_time = time.time()

for step in range(n_steps):
    loss = svi.step(data_2d)
    losses.append(loss)
    if step % 500 == 0:
        print(f"Step {step} - Loss: {loss:.2f}")

duration = time.time() - start_time
print(f"Обучение завершено за {duration:.2f} сек.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 14
#      11 start_time = time.time()
#      13 for step in range(n_steps):
# ---> 14     loss = svi.step(data_2d)
#      15     losses.append(loss)
#      16     if step % 500 == 0:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\svi.py:145, in SVI.step(self, *args, **kwargs)
#     143 # get loss and compute gradients
#     144 with poutine.trace(param_only=True) as param_capture:
# --> 145     loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     147 params = set(
#     148     site["value"].unconstrained() for site in param_capture.trace.nodes.values()
#     149 )
#     151 # actually perform gradient steps
#     152 # torch.optim objects gets instantiated for any params that haven't been seen yet
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\trace_elbo.py:140, in Trace_ELBO.loss_and_grads(self, model, guide, *args, **kwargs)
#     138 loss = 0.0
#     139 # grab a trace from the generator
# --> 140 for model_trace, guide_trace in self._get_traces(model, guide, args, kwargs):
#     141     loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(
#     142         model_trace, guide_trace
#     143     )
#     144     loss += loss_particle / self.num_particles
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\elbo.py:237, in ELBO._get_traces(self, model, guide, args, kwargs)
#     235 else:
#     236     for i in range(self.num_particles):
# --> 237         yield self._get_trace(model, guide, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\trace_elbo.py:57, in Trace_ELBO._get_trace(self, model, guide, args, kwargs)
#      52 def _get_trace(self, model, guide, args, kwargs):
#      53     """
#      54     Returns a single trace from the guide, and the model that is run
#      55     against it.
#      56     """
# ---> 57     model_trace, guide_trace = get_importance_trace(
#      58         "flat", self.max_plate_nesting, model, guide, args, kwargs
#      59     )
#      60     if is_validation_enabled():
#      61         check_if_enumerated(guide_trace)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\enum.py:60, in get_importance_trace(graph_type, max_plate_nesting, model, guide, args, kwargs, detach)
#      58     model_trace, guide_trace = unwrapped_guide.get_traces()
#      59 else:
# ---> 60     guide_trace = poutine.trace(guide, graph_type=graph_type).get_trace(
#      61         *args, **kwargs
#      62     )
#      63     if detach:
#      64         guide_trace.detach_()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\trace_messenger.py:216, in TraceHandler.get_trace(self, *args, **kwargs)
#     208 def get_trace(self, *args, **kwargs) -> Trace:
#     209     """
#     210     :returns: data structure
#     211     :rtype: pyro.poutine.Trace
#    (...)
#     214     Calls this poutine and returns its trace instead of the function's return value.
#     215     """
# --> 216     self(*args, **kwargs)
#     217     return self.msngr.get_trace()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     187 self.msngr.trace.add_node(
#     188     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     189 )
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#     193     exc_type, exc_value, traceback = sys.exc_info()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\nn\module.py:520, in PyroModule.__call__(self, *args, **kwargs)
#     518 def __call__(self, *args: Any, **kwargs: Any) -> Any:
#     519     with self._pyro_context:
# --> 520         result = super().__call__(*args, **kwargs)
#     521     if (
#     522         pyro.settings.get("validate_poutine")
#     523         and not self._pyro_context.active
#     524         and _is_module_local_param_enabled()
#     525     ):
#     526         self._check_module_local_param_usage()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\autoguide\guides.py:759, in AutoContinuous.forward(self, *args, **kwargs)
#     757 # if we've never run the model before, do so now so we can inspect the model structure
#     758 if self.prototype_trace is None:
# --> 759     self._setup_prototype(*args, **kwargs)
#     761 latent = self.sample_latent(*args, **kwargs)
#     762 plates = self._create_plates(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\autoguide\guides.py:938, in AutoDiagonalNormal._setup_prototype(self, *args, **kwargs)
#     937 def _setup_prototype(self, *args, **kwargs):
# --> 938     super()._setup_prototype(*args, **kwargs)
#     939     # Initialize guide params
#     940     self.loc = nn.Parameter(self._init_loc())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\autoguide\guides.py:636, in AutoContinuous._setup_prototype(self, *args, **kwargs)
#     635 def _setup_prototype(self, *args, **kwargs):
# --> 636     super()._setup_prototype(*args, **kwargs)
#     637     self._unconstrained_shapes = {}
#     638     self._cond_indep_stacks = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\autoguide\guides.py:157, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     154 def _setup_prototype(self, *args, **kwargs):
#     155     # run the model so we can inspect its structure
#     156     model = poutine.block(self.model, self._prototype_hide_fn)
# --> 157     self.prototype_trace = poutine.block(poutine.trace(model).get_trace)(
#     158         *args, **kwargs
#     159     )
#     160     if self.master is not None:
#     161         self.master()._check_prototype(self.prototype_trace)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\trace_messenger.py:216, in TraceHandler.get_trace(self, *args, **kwargs)
#     208 def get_trace(self, *args, **kwargs) -> Trace:
#     209     """
#     210     :returns: data structure
#     211     :rtype: pyro.poutine.Trace
#    (...)
#     214     Calls this poutine and returns its trace instead of the function's return value.
#     215     """
# --> 216     self(*args, **kwargs)
#     217     return self.msngr.get_trace()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     187 self.msngr.trace.add_node(
#     188     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     189 )
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#     193     exc_type, exc_value, traceback = sys.exc_info()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# Cell In[27], line 9, in model_mf(data, K)
#       7     locs = pyro.sample("locs", dist.Normal(torch.zeros(D), 1.0).to_event(1))
#       8     # Масштабы для каждого кластера
# ----> 9     scales = pyro.sample("scales", dist.LogNormal(torch.zeros(D), 1.0).to_event(1))
#      11 mixing_dist = dist.Categorical(weights)
#      12 # Объединение компонентов в одну смесь
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\primitives.py:189, in sample(name, fn, obs, obs_mask, infer, *args, **kwargs)
#     172 msg = Message(
#     173     type="sample",
#     174     name=name,
#    (...)
#     186     continuation=None,
#     187 )
#     188 # apply the stack and return its return value
# --> 189 apply_stack(msg)
#     190 assert msg["value"] is not None  # type narrowing guaranteed by apply_stack
#     191 return msg["value"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\runtime.py:378, in apply_stack(initial_msg)
#     375 for frame in reversed(stack):
#     376     pointer = pointer + 1
# --> 378     frame._process_message(msg)
#     380     if msg["stop"]:
#     381         break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\messenger.py:189, in Messenger._process_message(self, msg)
#     187 method = getattr(self, f"_pyro_{msg['type']}", None)
#     188 if method is not None:
# --> 189     method(msg)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\autoguide\initialization.py:237, in InitMessenger._pyro_sample(self, msg)
#     235     return
#     236 with torch.no_grad(), helpful_support_errors(msg):
# --> 237     value = self.init_fn(msg)
#     238 if is_validation_enabled() and msg["value"] is not None:
#     239     if not isinstance(value, type(msg["value"])):
#
# Cell In[34], line 8, in init_loc_fn(site)
#       6     return km_centers
#       7 if site["name"] == "scales":
# ----> 8     return torch.ones_like(site["value"]) # Начальный масштаб = 1
#       9 return init_to_median(site)
#
# TypeError: ones_like(): argument 'input' (position 1) must be Tensor, not NoneType

# %%
import torch
from matplotlib.patches import Ellipse

# 1. Извлекаем обученные центры и масштабы
with torch.no_grad():
    medians = guide_km.median()
    final_locs = medians['locs']
    final_scales = medians['scales']

# 2. Отрисовка
plt.figure(figsize=(10, 7))
plt.scatter(data_2d[:, 0], data_2d[:, 1], s=10, alpha=0.3, c='gray')
ax = plt.gca()

colors = ['#1f77b4', '#ff7f0e', '#d62728']
for i in range(len(final_locs)):
    # Рисуем эллипс 2-sigma
    #angle=0, так как модель DiagonalNormal не умеет вращать эллипсы
    el = Ellipse(xy=final_locs[i], width=4*final_scales[i, 0], height=4*final_scales[i, 1], 
                 angle=0, color=colors[i], fill=False, linewidth=3, label=f'Cluster {i}')
    ax.add_patch(el)

plt.title("Basic VI with K-means Initialization")
plt.legend()
plt.grid(True, alpha=0.2)
plt.show()

# %%
import pyro.distributions as dist

def model_full(data, K=3):
    D = data.shape[1]
    weights = pyro.sample("weights", dist.Dirichlet(torch.ones(K)))
    
    with pyro.plate("components", K):
        # Средние
        locs = pyro.sample("locs", dist.Normal(torch.zeros(D), 10.).to_event(1))
        
        # Работаем с матрицей ковариации через разложение Холецкого
        # 1. Масштабы (стандартные отклонения)
        scales = pyro.sample("scales", dist.HalfNormal(torch.ones(D)).to_event(1))
        # 2. Матрица корреляций (LKJ)
        # eta=1.0 означает априорное отсутствие предпочтений по форме
        corr_cholesky = pyro.sample("corr_cholesky", dist.LKJCholesky(D, eta=1.0))
        
        # Собираем матрицу: L = diag(scales) @ corr_cholesky
        L_omega = torch.diag_embed(scales) @ corr_cholesky

    # Смесь с MultivariateNormal
    mixing_dist = dist.Categorical(weights)
    component_dist = dist.MultivariateNormal(locs, scale_tril=L_omega)
    mixture = dist.MixtureSameFamily(mixing_dist, component_dist)
    
    with pyro.plate("data", len(data)):
        pyro.sample("obs", mixture, obs=data)

# Создаем Full Rank гайд
from pyro.infer.autoguide import AutoMultivariateNormal

pyro.clear_param_store()
# Используем ту же K-means инициализацию, что и раньше
guide_full = AutoMultivariateNormal(model_full, init_loc_fn=init_loc_fn)

# %%
import torch
import pyro
import pyro.distributions as dist
import time
from pyro.infer import SVI, Trace_ELBO
from pyro.infer.autoguide import AutoMultivariateNormal
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import numpy as np

# 1. Исправленная модель с полной матрицей ковариации
def model_full(data, K=3):
    D = data.shape[1]
    weights = pyro.sample("weights", dist.Dirichlet(torch.ones(K)))
    
    with pyro.plate("components", K):
        # Средние
        locs = pyro.sample("locs", dist.Normal(torch.zeros(D), 10.0).to_event(1))
        
        # Масштабы (отклонения)
        scales = pyro.sample("scales", dist.HalfNormal(torch.ones(D)).to_event(1))
        
        # Матрица корреляций (LKJ) - исправлен аргумент на concentration
        corr_cholesky = pyro.sample("corr_cholesky", dist.LKJCholesky(D, concentration=torch.tensor(1.0)))
        
        # Сборка матрицы Холецкого: L = diag(scales) @ corr_cholesky
        L_omega = torch.diag_embed(scales) @ corr_cholesky

    mixing_dist = dist.Categorical(weights)
    component_dist = dist.MultivariateNormal(locs, scale_tril=L_omega)
    mixture = dist.MixtureSameFamily(mixing_dist, component_dist)
    
    with pyro.plate("data", len(data)):
        pyro.sample("obs", mixture, obs=data)

# 2. Подготовка обучения
pyro.clear_param_store()

# Используем тот же init_loc_fn, который мы определили ранее для K-means
guide_full = AutoMultivariateNormal(model_full, init_loc_fn=init_loc_fn)

adam = pyro.optim.Adam({"lr": 0.01})
svi = SVI(model_full, guide_full, adam, loss=Trace_ELBO())

# 3. Цикл обучения
n_steps = 2000
losses_full = []

print("Начинаем обучение Full Rank VI...")
start_time = time.time()

for step in range(n_steps):
    loss = svi.step(data_2d)
    losses_full.append(loss)
    if step % 500 == 0:
        print(f"Step {step} - Loss: {loss:.2f}")

duration_full = time.time() - start_time
print(f"Обучение завершено за {duration_full:.2f} сек.")

# 4. Визуализация результата
def plot_full_rank_results(data, guide):
    with torch.no_grad():
        medians = guide.median()
        locs = medians['locs'].numpy()
        scales = medians['scales'].numpy()
        corr_cholesky = medians['corr_cholesky'].numpy()
        
    plt.figure(figsize=(10, 7))
    plt.scatter(data[:, 0], data[:, 1], s=10, alpha=0.3, c='gray')
    ax = plt.gca()
    colors = ['#1f77b4', '#ff7f0e', '#d62728']
    
    for i in range(len(locs)):
        # Матрица ковариации Sigma = L @ L.T
        L = np.diag(scales[i]) @ corr_cholesky[i]
        cov = L @ L.T
        
        # Вычисляем форму эллипса
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        vals, vecs = vals[order], vecs[:, order]
        theta = np.degrees(np.arctan2(*vecs[:, 0][::-1]))
        width, height = 4 * np.sqrt(vals) # 2-sigma
        
        el = Ellipse(xy=locs[i], width=width, height=height, angle=theta,
                     edgecolor=colors[i], fill=False, linewidth=3, label=f'Cluster {i}')
        ax.add_patch(el)

    plt.title(f"Full Rank VI Results (Time: {duration_full:.2f}s)")
    plt.legend()
    plt.grid(True, alpha=0.2)
    plt.show()

plot_full_rank_results(data_2d, guide_full)
# Out:
# Начинаем обучение Full Rank VI...
# Step 0 - Loss: 17510.92
# Step 500 - Loss: 6935.35
# Step 1000 - Loss: 6908.16
# Step 1500 - Loss: 6912.28
# Обучение завершено за 25.61 сек.

# %%
from pyro.infer import MCMC, NUTS

def model_mcmc(data, K=3):
    D = data.shape[1]
    weights = pyro.sample("weights", dist.Dirichlet(torch.ones(K)))
    
    with pyro.plate("components", K):
        locs = pyro.sample("locs", dist.Normal(torch.zeros(D), 10.0).to_event(1))
        scales = pyro.sample("scales", dist.HalfNormal(torch.ones(D)).to_event(1))
        corr_cholesky = pyro.sample("corr_cholesky", dist.LKJCholesky(D, concentration=1.0))
        L_omega = torch.diag_embed(scales) @ corr_cholesky

    # Для MCMC часто стабильнее использовать явную смесь через log_sum_exp
    # Но для учебных целей оставим MixtureSameFamily, если данных не слишком много
    component_dist = dist.MultivariateNormal(locs, scale_tril=L_omega)
    mixture = dist.MixtureSameFamily(dist.Categorical(weights), component_dist)
    
    with pyro.plate("data", len(data)):
        pyro.sample("obs", mixture, obs=data)

# %%
def run_mcmc(warmup, num_samples=300):
    pyro.clear_param_store()
    nuts_kernel = NUTS(model_mcmc)
    mcmc = MCMC(nuts_kernel, num_samples=num_samples, warmup_steps=warmup)
    
    start_time = time.time()
    mcmc.run(data_2d)
    duration = time.time() - start_time
    
    print(f"MCMC ({warmup} warmup) завершен за {duration:.2f} сек.")
    return mcmc, duration

# Запускаем два варианта
mcmc_20, time_20 = run_mcmc(20)
mcmc_100, time_100 = run_mcmc(100)
# Out:
# Sample: 100%|█████████████████████████████████████████| 320/320 [00:25, 12.53it/s, step size=1.19e-01, acc. prob=0.102]
# MCMC (20 warmup) завершен за 25.55 сек.
# Sample: 100%|█████████████████████████████████████████| 400/400 [03:42,  1.80it/s, step size=5.86e-03, acc. prob=0.905]
# MCMC (100 warmup) завершен за 222.05 сек.

# %%
import arviz as az

# Конвертируем данные Pyro в формат ArviZ
data_az_20 = az.from_pyro(mcmc_20)
data_az_100 = az.from_pyro(mcmc_100)

# 1. Trace Plots (Смотрим, насколько "пушистые" графики)
az.plot_trace(data_az_100, var_names=["locs"])
plt.show()

# 2. Summary (R-hat должен быть близок к 1.0)
print(az.summary(data_az_100, var_names=["locs", "weights"]))

# 3. Autocorrelation (Смотрим, как быстро затухает зависимость)
az.plot_autocorr(data_az_100, var_names=["locs"], combined=True)
plt.show()
# Out:
# C:\Users\Piligrim\AppData\Local\Programs\Python\Python312\Lib\site-packages\arviz\data\io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(
# arviz - WARNING - Shape validation failed: input_shape: (1, 300), minimum_shape: (chains=2, draws=4)
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# locs[0, 0]  4.818  0.123   4.607    5.063      0.006    0.007     378.0
# locs[0, 1]  4.855  0.129   4.621    5.078      0.006    0.012     482.0
# locs[1, 0]  3.503  0.012   3.480    3.523      0.001    0.001     277.0
# locs[1, 1]  5.501  0.012   5.478    5.524      0.001    0.001     290.0
# locs[2, 0]  7.550  0.098   7.386    7.722      0.006    0.006     328.0
# locs[2, 1]  2.537  0.093   2.335    2.679      0.008    0.006     146.0
# weights[0]  0.407  0.015   0.382    0.436      0.001    0.001     250.0
# weights[1]  0.198  0.010   0.177    0.213      0.001    0.001     273.0
# weights[2]  0.395  0.015   0.370    0.424      0.001    0.001     297.0
#
#             ess_tail  r_hat
# locs[0, 0]     229.0    NaN
# locs[0, 1]     213.0    NaN
# locs[1, 0]     181.0    NaN
# locs[1, 1]     202.0    NaN
# locs[2, 0]     147.0    NaN
# locs[2, 1]     169.0    NaN
# weights[0]     219.0    NaN
# weights[1]     204.0    NaN
# weights[2]     162.0    NaN

# %%
samples = mcmc_100.get_samples()
mean_locs = samples['locs'].mean(0)
mean_scales = samples['scales'].mean(0)
mean_corr = samples['corr_cholesky'].mean(0)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

def plot_mcmc_results(data, mcmc_obj, title="MCMC Results"):
    # Извлекаем все сэмплы
    samples = mcmc_obj.get_samples()
    
    # Считаем среднее по всем сэмплам (индекс 0 — это количество шагов)
    with torch.no_grad():
        locs = samples['locs'].mean(0).numpy()        # [K, 2]
        scales = samples['scales'].mean(0).numpy()    # [K, 2]
        corr_cholesky = samples['corr_cholesky'].mean(0).numpy() # [K, 2, 2]

    plt.figure(figsize=(10, 7))
    plt.scatter(data[:, 0], data[:, 1], s=10, alpha=0.3, c='gray')
    ax = plt.gca()
    colors = ['#1f77b4', '#ff7f0e', '#d62728']
    
    for i in range(len(locs)):
        # Восстанавливаем матрицу ковариации из средних значений
        L = np.diag(scales[i]) @ corr_cholesky[i]
        cov = L @ L.T
        
        # Считаем геометрию эллипса
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        vals, vecs = vals[order], vecs[:, order]
        theta = np.degrees(np.arctan2(*vecs[:, 0][::-1]))
        width, height = 4 * np.sqrt(vals) # 2-sigma
        
        el = Ellipse(xy=locs[i], width=width, height=height, angle=theta,
                     edgecolor=colors[i], fill=False, linewidth=3, label=f'Cluster {i}')
        ax.add_patch(el)

    plt.title(title)
    plt.legend()
    plt.grid(True, alpha=0.2)
    plt.show()

# %%
from pyro.infer import MCMC, NUTS

# 1. Настройка ядра
nuts_kernel = NUTS(model_full) # Используем ту же модель, что в 1.2

# 2. Запуск с warmup=20
print("Запуск MCMC (warmup=20)...")
mcmc_20 = MCMC(nuts_kernel, num_samples=300, warmup_steps=20)
mcmc_20.run(data_2d)
plot_mcmc_results(data_2d, mcmc_20, "MCMC (Warmup: 20)")

# 3. Запуск с warmup=100
print("Запуск MCMC (warmup=100)...")
mcmc_100 = MCMC(nuts_kernel, num_samples=300, warmup_steps=100)
mcmc_100.run(data_2d)
plot_mcmc_results(data_2d, mcmc_100, "MCMC (Warmup: 100)")
# Out:
# Запуск MCMC (warmup=20)...
# Sample: 100%|█████████████████████████████████████████| 320/320 [00:39,  8.06it/s, step size=1.04e-01, acc. prob=0.101]
# Запуск MCMC (warmup=100)...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 14
#      12 # 3. Запуск с warmup=100
#      13 print("Запуск MCMC (warmup=100)...")
# ---> 14 mcmc_100 = MCMC(nuts_kernel, num_samples=300, warmup_steps=100)
#      15 mcmc_100.run(data_2d)
#      16 plot_mcmc_results(data_2d, mcmc_100, "MCMC (Warmup: 100)")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\api.py:478, in MCMC.__init__(self, kernel, num_samples, warmup_steps, initial_params, num_chains, hook_fn, mp_context, disable_progbar, disable_validation, transforms, save_params)
#     476 if save_params is not None:
#     477     kernel.save_params = save_params
# --> 478 self._validate_kernel(initial_params)
#     479 parallel = False
#     480 if num_chains > 1:
#     481     # check that initial_params is different for each chain
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\api.py:391, in AbstractMCMC._validate_kernel(self, initial_params)
#     386 if (
#     387     isinstance(self.kernel, (HMC, NUTS))
#     388     and self.kernel.potential_fn is not None
#     389 ):
#     390     if initial_params is None:
# --> 391         raise ValueError(
#     392             "Must provide valid initial parameters to begin sampling"
#     393             " when using `potential_fn` in HMC/NUTS kernel."
#     394         )
#
# ValueError: Must provide valid initial parameters to begin sampling when using `potential_fn` in HMC/NUTS kernel.

# %%
# 1. Готовим начальные значения (используем те же km_centers из 1.1)
init_params = {
    "locs": km_centers, 
    "weights": torch.ones(3) / 3, # Равные веса
    "scales": torch.ones(3, 2),    # Начальный разброс = 1
    "corr_cholesky": torch.eye(2).repeat(3, 1, 1) # Начальная корреляция — единичная матрица
}

# 2. Настраиваем MCMC
nuts_kernel = NUTS(model_full, init_strategy=init_to_median) # Базовая стратегия
mcmc_100 = MCMC(nuts_kernel, num_samples=300, warmup_steps=100)

# 3. Запускаем, передавая начальные параметры
print("Запуск MCMC с явной инициализацией...")
mcmc_100.run(data_2d, initial_params=init_params)

# 4. Рисуем результат
plot_mcmc_results(data_2d, mcmc_100, "MCMC (Warmup: 100) with K-means Init")
# Out:
# Запуск MCMC с явной инициализацией...
# Warmup:   0%|                                                                                    | 0/400 [00:00, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 15
#      13 # 3. Запускаем, передавая начальные параметры
#      14 print("Запуск MCMC с явной инициализацией...")
# ---> 15 mcmc_100.run(data_2d, initial_params=init_params)
#      17 # 4. Рисуем результат
#      18 plot_mcmc_results(data_2d, mcmc_100, "MCMC (Warmup: 100) with K-means Init")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\api.py:565, in MCMC.run(self, *args, **kwargs)
#     556 with optional(
#     557     pyro.validation_enabled(not self.disable_validation),
#     558     self.disable_validation is not None,
#    (...)
#     562     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#     563     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     564     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 565     for x, chain_id in self.sampler.run(*args, **kwargs):
#     566         if num_samples[chain_id] == 0:
#     567             num_samples[chain_id] += 1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\api.py:225, in _UnarySampler.run(self, *args, **kwargs)
#     223 logger = initialize_logger(logger, "", progress_bar)
#     224 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 225 for sample in _gen_samples(
#     226     self.kernel,
#     227     self.warmup_steps,
#     228     self.num_samples,
#     229     hook_w_logging,
#     230     i if self.num_chains > 1 else None,
#     231     *args,
#     232     **kwargs
#     233 ):
#     234     yield sample, i  # sample, chain_id
#     235 self.kernel.cleanup()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\api.py:146, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     145 def _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs):
# --> 146     kernel.setup(warmup_steps, *args, **kwargs)
#     147     params = kernel.initial_params
#     148     save_params = getattr(kernel, "save_params", sorted(params))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\hmc.py:345, in HMC.setup(self, warmup_steps, *args, **kwargs)
#     343 self._warmup_steps = warmup_steps
#     344 if self.model is not None:
# --> 345     self._initialize_model_properties(args, kwargs)
#     346 if self.initial_params:
#     347     z = {k: v.detach() for k, v in self.initial_params.items()}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\hmc.py:279, in HMC._initialize_model_properties(self, model_args, model_kwargs)
#     278 def _initialize_model_properties(self, model_args, model_kwargs):
# --> 279     init_params, potential_fn, transforms, trace = initialize_model(
#     280         self.model,
#     281         model_args,
#     282         model_kwargs,
#     283         transforms=self.transforms,
#     284         max_plate_nesting=self._max_plate_nesting,
#     285         jit_compile=self._jit_compile,
#     286         jit_options=self._jit_options,
#     287         skip_jit_warnings=self._ignore_jit_warnings,
#     288         init_strategy=self._init_strategy,
#     289         initial_params=self._initial_params,
#     290     )
#     291     self.potential_fn = potential_fn
#     292     self.transforms = transforms
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\util.py:427, in initialize_model(model, model_args, model_kwargs, transforms, max_plate_nesting, jit_compile, jit_options, skip_jit_warnings, num_chains, init_strategy, initial_params)
#     425     automatic_transform_enabled = False
#     426 if max_plate_nesting is None:
# --> 427     max_plate_nesting = _guess_max_plate_nesting(model, model_args, model_kwargs)
#     428 # Wrap model in `poutine.enum` to enumerate over discrete latent sites.
#     429 # No-op if model does not have any discrete latents.
#     430 model = poutine.enum(
#     431     config_enumerate(model), first_available_dim=-1 - max_plate_nesting
#     432 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\infer\mcmc\util.py:251, in _guess_max_plate_nesting(model, args, kwargs)
#     245 """
#     246 Guesses max_plate_nesting by running the model once
#     247 without enumeration. This optimistically assumes static model
#     248 structure.
#     249 """
#     250 with poutine.block():
# --> 251     model_trace = poutine.trace(model).get_trace(*args, **kwargs)
#     252 sites = [site for site in model_trace.nodes.values() if site["type"] == "sample"]
#     254 dims = [
#     255     frame.dim
#     256     for site in sites
#     257     for frame in site["cond_indep_stack"]
#     258     if frame.vectorized
#     259 ]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\trace_messenger.py:216, in TraceHandler.get_trace(self, *args, **kwargs)
#     208 def get_trace(self, *args, **kwargs) -> Trace:
#     209     """
#     210     :returns: data structure
#     211     :rtype: pyro.poutine.Trace
#    (...)
#     214     Calls this poutine and returns its trace instead of the function's return value.
#     215     """
# --> 216     self(*args, **kwargs)
#     217     return self.msngr.get_trace()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyro\poutine\trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     187 self.msngr.trace.add_node(
#     188     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     189 )
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#     193     exc_type, exc_value, traceback = sys.exc_info()
#
# TypeError: model_full() got an unexpected keyword argument 'initial_params'

# %%
def model_sparse(data, K=10):
    D = data.shape[1]
    # Используем альфа = 0.1 для разреженности
    weights = pyro.sample("weights", dist.Dirichlet(torch.ones(K) * 0.1))
    
    with pyro.plate("components", K):
        locs = pyro.sample("locs", dist.Normal(torch.zeros(D), 10.).to_event(1))
        scales = pyro.sample("scales", dist.HalfNormal(torch.ones(D)).to_event(1))
        corr_cholesky = pyro.sample("corr_cholesky", dist.LKJCholesky(D, concentration=1.0))
        L_omega = torch.diag_embed(scales) @ corr_cholesky

    mixture = dist.MixtureSameFamily(dist.Categorical(weights), dist.MultivariateNormal(locs, scale_tril=L_omega))
    with pyro.plate("data", len(data)):
        pyro.sample("obs", mixture, obs=data)

# Запуск VI (инициализация init_to_median по условию)
pyro.clear_param_store()
guide_sparse = AutoMultivariateNormal(model_sparse, init_loc_fn=init_to_median)
svi = SVI(model_sparse, guide_sparse, pyro.optim.Adam({"lr": 0.01}), loss=Trace_ELBO())

for i in range(2000):
    svi.step(data_2d)

# %%
def plot_sparse_results(data, guide):
    with torch.no_grad():
        medians = guide.median()
        locs = medians['locs'].numpy()
        scales = medians['scales'].numpy()
        corr_cholesky = medians['corr_cholesky'].numpy()
        weights = medians['weights'].numpy()
        
    plt.figure(figsize=(10, 7))
    plt.scatter(data[:, 0], data[:, 1], s=10, alpha=0.2, c='gray')
    ax = plt.gca()
    
    for i in range(len(weights)):
        L = np.diag(scales[i]) @ corr_cholesky[i]
        cov = L @ L.T
        vals, vecs = np.linalg.eigh(cov)
        theta = np.degrees(np.arctan2(*vecs[:, 0][::-1]))
        width, height = 4 * np.sqrt(vals)
        
        # Условие по весу
        color = 'red' if weights[i] > 0.05 else 'lightgray'
        alpha = 0.8 if weights[i] > 0.05 else 0.3
        
        el = Ellipse(xy=locs[i], width=width, height=height, angle=theta,
                     edgecolor=color, fill=False, linewidth=2, alpha=alpha)
        ax.add_patch(el)
    plt.title(f"Sparse Dirichlet Clustering (K=10, alpha=0.1). Weights: {np.round(weights, 2)}")
    plt.show()

plot_sparse_results(data_2d, guide_sparse)

# %% [markdown]
# ## Автоматизация прогонов (разные seed) + выводы
#
# Ниже — служебные функции и прогоны, чтобы **выполнить требование “запустить VI несколько раз с разными seed”** и сравнить:
#
# - Basic VI (AutoDiagonalNormal) с **init_to_median**
# - Basic VI (AutoDiagonalNormal) с **KMeans-инициализацией**
# - Full Rank VI (AutoMultivariateNormal + LKJCholesky) с **init_to_median**
# - Full Rank VI (AutoMultivariateNormal + LKJCholesky) с **KMeans-инициализацией**
#
# Для каждого прогона сохраняем **время**, рисуем **ELBO/Loss**, и строим **эллипсы 2-sigma** поверх данных.

# %%
# --- Утилиты для повторяемых запусков ---

def set_all_seeds(seed: int):
    pyro.set_rng_seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)


def run_svi_once(
    *,
    model,
    guide_cls,
    init_loc_fn,
    seed: int,
    data,
    n_steps: int = 2000,
    lr: float = 0.01,
    label: str = "run",
):
    """Запуск одного SVI-прогона + возврат loss, времени и median-параметров."""
    set_all_seeds(seed)
    pyro.clear_param_store()

    guide = guide_cls(model, init_loc_fn=init_loc_fn)
    svi = SVI(model, guide, pyro.optim.Adam({"lr": lr}), loss=Trace_ELBO())

    losses = []
    t0 = time.time()
    for _ in range(n_steps):
        losses.append(svi.step(data))
    dt = time.time() - t0

    with torch.no_grad():
        med = guide.median()

    print(f"[{label}] seed={seed} | steps={n_steps} | time={dt:.2f}s | final_loss={losses[-1]:.2f}")
    return {
        "seed": seed,
        "time": dt,
        "losses": losses,
        "median": med,
    }


def plot_loss_curves(runs, title: str):
    plt.figure(figsize=(9, 4))
    for r in runs:
        plt.plot(r["losses"], label=f"seed={r['seed']} ({r['time']:.1f}s)")
    plt.title(title)
    plt.xlabel("step")
    plt.ylabel("ELBO loss")
    plt.grid(True, alpha=0.2)
    plt.legend()
    plt.show()


def plot_diag_ellipses_from_median(data, med, title: str):
    """Для Basic VI: эллипсы без поворота (diag scales)."""
    with torch.no_grad():
        locs = med["locs"].cpu().numpy()
        scales = med["scales"].cpu().numpy()

    plt.figure(figsize=(10, 7))
    plt.scatter(data[:, 0], data[:, 1], s=10, alpha=0.3, c="gray")
    ax = plt.gca()
    colors = ["#1f77b4", "#ff7f0e", "#d62728"]

    for i in range(locs.shape[0]):
        el = Ellipse(
            xy=locs[i],
            width=4 * scales[i, 0],
            height=4 * scales[i, 1],
            angle=0,
            edgecolor=colors[i % len(colors)],
            fill=False,
            linewidth=3,
            label=f"Cluster {i}",
        )
        ax.add_patch(el)

    plt.title(title)
    plt.legend()
    plt.grid(True, alpha=0.2)
    plt.show()


def plot_full_ellipses_from_median(data, med, title: str):
    """Для Full Rank VI: эллипсы с поворотом (ковариация из L @ L.T)."""
    locs = med["locs"].cpu().numpy()
    scales = med["scales"].cpu().numpy()
    corr_cholesky = med["corr_cholesky"].cpu().numpy()

    plt.figure(figsize=(10, 7))
    plt.scatter(data[:, 0], data[:, 1], s=10, alpha=0.3, c="gray")
    ax = plt.gca()
    colors = ["#1f77b4", "#ff7f0e", "#d62728"]

    for i in range(locs.shape[0]):
        L = np.diag(scales[i]) @ corr_cholesky[i]
        cov = L @ L.T
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        vals, vecs = vals[order], vecs[:, order]
        theta = np.degrees(np.arctan2(*vecs[:, 0][::-1]))
        width, height = 4 * np.sqrt(vals)

        el = Ellipse(
            xy=locs[i],
            width=width,
            height=height,
            angle=theta,
            edgecolor=colors[i % len(colors)],
            fill=False,
            linewidth=3,
            label=f"Cluster {i}",
        )
        ax.add_patch(el)

    plt.title(title)
    plt.legend()
    plt.grid(True, alpha=0.2)
    plt.show()


# --- Инициализации (init_to_median и KMeans) ---

def make_kmeans_init_fn(data, K: int):
    # В sklearn KMeans есть случайность => фиксируем random_state через np.seed/pyro seed выше.
    km = KMeans(n_clusters=K, n_init=10, random_state=0).fit(data.detach().cpu().numpy())
    centers = torch.tensor(km.cluster_centers_, dtype=torch.float)

    def init_loc_fn(site):
        if site["name"] == "locs":
            return centers
        if site["name"] == "scales":
            return torch.ones_like(site["value"])
        return init_to_median(site)

    return init_loc_fn


# --- 1.1 Basic VI: несколько seed ---

basic_seeds = [0, 1, 2]

runs_basic_default = [
    run_svi_once(
        model=model_mf,
        guide_cls=AutoDiagonalNormal,
        init_loc_fn=init_to_median,
        seed=s,
        data=data_2d,
        label="Basic VI (init_to_median)",
    )
    for s in basic_seeds
]
plot_loss_curves(runs_basic_default, "Basic VI (AutoDiagonalNormal) — разные seed (init_to_median)")
plot_diag_ellipses_from_median(data_2d.numpy(), runs_basic_default[0]["median"], "Basic VI — эллипсы (пример: seed=0)")

init_loc_fn_km_basic = make_kmeans_init_fn(data_2d, K=3)

runs_basic_km = [
    run_svi_once(
        model=model_mf,
        guide_cls=AutoDiagonalNormal,
        init_loc_fn=init_loc_fn_km_basic,
        seed=s,
        data=data_2d,
        label="Basic VI (KMeans init)",
    )
    for s in basic_seeds
]
plot_loss_curves(runs_basic_km, "Basic VI (AutoDiagonalNormal) — разные seed (KMeans init)")
plot_diag_ellipses_from_median(data_2d.numpy(), runs_basic_km[0]["median"], "Basic VI + KMeans init — эллипсы (пример: seed=0)")


# --- 1.2 Full Rank VI: несколько seed ---

full_seeds = [0, 1, 2]

runs_full_default = [
    run_svi_once(
        model=model_full,
        guide_cls=AutoMultivariateNormal,
        init_loc_fn=init_to_median,
        seed=s,
        data=data_2d,
        label="Full Rank VI (init_to_median)",
    )
    for s in full_seeds
]
plot_loss_curves(runs_full_default, "Full Rank VI (AutoMultivariateNormal) — разные seed (init_to_median)")
plot_full_ellipses_from_median(data_2d.numpy(), runs_full_default[0]["median"], "Full Rank VI — эллипсы (пример: seed=0)")

init_loc_fn_km_full = make_kmeans_init_fn(data_2d, K=3)

runs_full_km = [
    run_svi_once(
        model=model_full,
        guide_cls=AutoMultivariateNormal,
        init_loc_fn=init_loc_fn_km_full,
        seed=s,
        data=data_2d,
        label="Full Rank VI (KMeans init)",
    )
    for s in full_seeds
]
plot_loss_curves(runs_full_km, "Full Rank VI (AutoMultivariateNormal) — разные seed (KMeans init)")
plot_full_ellipses_from_median(data_2d.numpy(), runs_full_km[0]["median"], "Full Rank VI + KMeans init — эллипсы (пример: seed=0)")

# %% [markdown]
# ## Комментарии по результатам (коротко)
#
# - **Почему Basic VI (диагональная ковариация) может быть неадекватен**: если настоящий кластер вытянут/повёрнут (корреляция между осями), диагональная модель не умеет повернуть эллипс и вынуждена либо делать его «толстым», либо промахиваться по форме.
# - **Почему Full Rank VI лучше описывает данные**: полная ковариация (через `LKJCholesky`) позволяет **поворот** эллипсов (ненулевая корреляция), поэтому вытянутые кластеры описываются реалистичнее.
# - **Цена**: Full Rank VI оптимизирует больше параметров → обычно **дольше** и может быть менее стабильным по seed.
# - **KMeans-инициализация**: как эмпирический Байес помогает задать старт в разумной области и уменьшает риск “плохого” локального минимума VI.
#
# Адекватность на твоих данных:
# - Для кластера B (вытянутого по диагонали) **Basic VI ожидаемо хуже**, Full Rank должен давать заметно лучшее совпадение формы.

# %%
# --- 2) MCMC/NUTS: сравнение warmup=20 vs 100 с диагностикой для ОБОИХ ---
# Важно: чтобы R-hat был осмысленным, нужно >=2 цепей.


def run_mcmc_with_diagnostics(*, model, data, warmup: int, num_samples: int = 300, num_chains: int = 2, label: str = "MCMC"):
    set_all_seeds(0)
    nuts = NUTS(model, init_strategy=init_to_median)
    mcmc = MCMC(nuts, num_samples=num_samples, warmup_steps=warmup, num_chains=num_chains)

    t0 = time.time()
    mcmc.run(data)
    dt = time.time() - t0

    print(f"[{label}] warmup={warmup}, samples={num_samples}, chains={num_chains} | time={dt:.2f}s")

    # ArviZ diagnostics
    data_az = az.from_pyro(mcmc)
    print(az.summary(data_az, var_names=["weights", "locs"], round_to=2))
    az.plot_trace(data_az, var_names=["weights", "locs"])
    az.plot_autocorr(data_az, var_names=["locs"], combined=True)

    # Ellipses
    plot_mcmc_results(data_2d.numpy(), mcmc, f"{label} (warmup={warmup}, time={dt:.1f}s)")

    return mcmc, dt


# Сравнение warmup
mcmc20, t20 = run_mcmc_with_diagnostics(model=model_full, data=data_2d, warmup=20, label="NUTS Full model")
mcmc100, t100 = run_mcmc_with_diagnostics(model=model_full, data=data_2d, warmup=100, label="NUTS Full model")

# %% [markdown]
# ## Ответы на вопросы (по смыслу задания)
#
# ### Почему VI на порядки быстрее MCMC на больших данных, но может давать смещённую дисперсию?
# - **VI** решает задачу оптимизации (градиентами) и часто использует факторизованные/упрощённые семейства постериора → быстро масштабируется по данным.
# - **MCMC (NUTS)** должен «обойти» постериор в пространстве параметров, генерируя коррелированные сэмплы, и каждый шаг требует прогонов модели → на больших данных становится очень дорогим.
# - **Смещение дисперсии в VI**: mean-field / ограниченное семейство приближений часто ведёт к **занижению дисперсий** (постериор «схлопывается»), т.к. минимизация KL(q||p) штрафует за “выход” q в области, где p мала.
#
# ### “Честно” ли использовать K-means для инициализации байесовской модели?
# - Это **эмпирический Байес / data-dependent init**: стартовые параметры зависят от данных.
# - Обычно считается приемлемым как **численный трюк** для стабильности оптимизации/сэмплинга, если ты **не выдаёшь KMeans-результат за априор** и явно пишешь, что это инициализация.
#
# ### Как sparsity prior Dirichlet помогает выбирать число кластеров?
# - При маленькой α (например, 0.1) априор стимулирует **разреженные веса**: многие компоненты получают вес близкий к 0.
# - Если задать K больше нужного, “лишние” кластеры автоматически получат малые веса → это способ **автоматически выключать компоненты**.
#
# ### Почему NUTS стал ещё медленнее при K=10, α=0.1?
# - **Размерность параметров выросла** (больше `locs`, `scales`, `corr_cholesky`, `weights`).
# - Постериор становится более **мультимодальным** и сложным (перестановочная симметрия компонент, сильная корреляция параметров).
# - NUTS приходится тратить больше шагов на адаптацию/переходы → эффективных независимых сэмплов меньше, время больше.

# %%
# --- K=10, alpha=0.1: NUTS на разреженной модели (для сравнения с Full Rank VI) ---
# ВНИМАНИЕ: может быть существенно медленнее, чем K=3.


def run_sparse_nuts(*, warmup: int = 100, num_samples: int = 300, num_chains: int = 2):
    nuts = NUTS(model_sparse, init_strategy=init_to_median)
    mcmc = MCMC(nuts, num_samples=num_samples, warmup_steps=warmup, num_chains=num_chains)

    t0 = time.time()
    mcmc.run(data_2d)
    dt = time.time() - t0

    print(f"[NUTS sparse] warmup={warmup}, samples={num_samples}, chains={num_chains} | time={dt:.2f}s")

    data_az = az.from_pyro(mcmc)
    print(az.summary(data_az, var_names=["weights"], round_to=3))
    az.plot_trace(data_az, var_names=["weights"])

    # Эллипсы для всех K=10 можно рисовать, но будет перегружено; здесь оставим веса как основной сигнал.
    return mcmc, dt


# Запуск (можно уменьшить num_samples, если слишком долго)
# sparse_mcmc, sparse_time = run_sparse_nuts(warmup=100, num_samples=300, num_chains=2)
